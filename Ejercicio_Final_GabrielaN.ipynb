# %% [markdown]
# # Ejercicio 12 y 13 - Cuaderno Final JupyterLite

# %% [markdown]
# ## Introducción
# Este cuaderno contiene los ejercicios solicitados para completar la tarea del curso, enfocándose en la compartición en GitHub y la captura de pantalla.

# %% [markdown]
# ## Instrucciones
# 1. Ejecuta las celdas de código.
# 2. Completa los ejercicios 12 y 13.
# 3. Sube este archivo `.ipynb` a GitHub.
# 4. Toma la captura de pantalla de la primera página.

# %% [markdown]
# ## Objetivos
# - Subir el cuaderno a un repositorio público de GitHub (Ejercicio 12).
# - Tomar captura de pantalla de la primera página (Ejercicio 13).

# %%
a = 5
b = 3
suma = a + b
print(f"La suma de {a} y {b} es: {suma}")

# %%
for i in range(1, 4):
    print(f"Iteración número {i}")

# %% [markdown]
# > “La práctica hace al maestro.” – Proverbio popular

# %% [markdown]
# ### Tabla de contenidos
#
# | Sección | Tipo de celda | Descripción |
# |---------|--------------|-------------|
# | 1 | Markdown | Título |
# | 2 | Markdown | Introducción |
# | 3 | Markdown | Instrucciones |
# | 4 | Markdown | Objetivos |
# | 5 | Code | Ejemplo de suma |
# | 6 | Code | Ejemplo de bucle |
# | 7 | Markdown | Cita |
# | 8 | Markdown | Tabla |
# | 9 | Markdown | Imagen |
# | 10| Markdown | Conclusión |

# %% [markdown]
# ### Imagen ilustrativa
#
# ![Python logo](https://www.python.org/static/community_logos/python-logo.png)

# %% [markdown]
# ## Conclusión
# Este cuaderno demuestra cómo combinar celdas Markdown bien formateadas con código funcional. Ahora puedes subirlo a GitHub y tomar la captura de pantalla de la primera página.
